# %%
# Downloading NLTK data for NER

nltk.download('maxent_ne_chunker')

nltk.download('words')

nltk.download('punkt')

nltk.download('averaged_perceptron_tagger')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 # Downloading NLTK data for NER
#       2
# ----> 3 nltk.download('maxent_ne_chunker')
#       4
#       5 nltk.download('words')
#       6
#
# NameError: name 'nltk' is not defined

# %%
# !pip install nltk
# Out:
# Collecting nltk
#   Using cached nltk-3.9.4-py3-none-any.whl.metadata (3.2 kB)
# Collecting click (from nltk)
#   Downloading click-8.4.2-py3-none-any.whl.metadata (2.6 kB)
# Collecting joblib (from nltk)
#   Using cached joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# Collecting regex>=2021.8.3 (from nltk)
#   Downloading regex-2026.6.28-cp314-cp314-win_amd64.whl.metadata (41 kB)
# Collecting tqdm (from nltk)
#   Downloading tqdm-4.68.3-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: colorama in c:\users\khara\onedrive\desktop\ai prompt engineering\venv\lib\site-packages (from click->nltk) (0.4.6)
# Using cached nltk-3.9.4-py3-none-any.whl (1.6 MB)
# Downloading regex-2026.6.28-cp314-cp314-win_amd64.whl (280 kB)
# Downloading click-8.4.2-py3-none-any.whl (119 kB)
# Using cached joblib-1.5.3-py3-none-any.whl (309 kB)
# Downloading tqdm-4.68.3-py3-none-any.whl (78 kB)
# Installing collected packages: tqdm, regex, joblib, click, nltk
#
#    -------- ------------------------------- 1/5 [regex]
#    ---------------- ----------------------- 2/5 [joblib]
#    ---------------- ----------------------- 2/5 [joblib]
#    ---------------- ----------------------- 2/5 [joblib]
#    ------------------------ --------------- 3/5 [click]
#    ------------------------ --------------- 3/5 [click]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    ---------------------------------------- 5/5 [nltk]
#
# Successfully installed click-8.4.2 joblib-1.5.3 nltk-3.9.4 regex-2026.6.28 tqdm-4.68.3
# [notice] A new release of pip is available: 25.2 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Sample business document

business_document = """

The recent feedback from Acme Corp highlighted issues with the new model of the Omega widget.

Customers from New York and San Francisco have reported delays in shipping.

The CEO of Acme Corp, Jane Doe, mentioned plans to address these concerns by Q3.

"""

# %%
# Tokenizing the document

nltk.download('maxent_ne_chunker')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 3
#       1 # Tokenizing the document
#       2
# ----> 3 nltk.download('maxent_ne_chunker')
#       4
#
# NameError: name 'nltk' is not defined

# %%
# Applying NER

ner_result = nltk.ne_chunk(nltk.pos_tag(tokens))

# %%
# Printing named entities

print("Named Entities:")

for entity in ner_result:

    if isinstance(entity, nltk.Tree):

        print(" ".join([word for word, tag in entity.leaves()]))
