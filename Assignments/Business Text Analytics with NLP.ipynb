# %%
# !pip install nltk spacy transformers pandas
# Out:
# ...
#   Using cached pydantic-2.13.4-py3-none-any.whl.metadata (109 kB)
# ...
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# ...
#   Using cached pydantic_core-2.46.4-cp314-cp314-win_amd64.whl.metadata (6.7 kB)
# ...
#   Using cached typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# ...
#   Using cached shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# ...
#   Using cached rich-15.0.0-py3-none-any.whl.metadata (18 kB)
# ...
#   Using cached annotated_doc-0.0.4-py3-none-any.whl.metadata (6.6 kB)
# ...
#   Using cached tokenizers-0.22.2-cp39-abi3-win_amd64.whl.metadata (7.4 kB)
# ...
#   Using cached safetensors-0.8.0-cp310-abi3-win_amd64.whl.metadata (4.2 kB)
# ...
#   Using cached hf_xet-1.5.1-cp37-abi3-win_amd64.whl.metadata (4.9 kB)
# ...
#   Using cached markdown_it_py-4.2.0-py3-none-any.whl.metadata (7.4 kB)
# ...
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# ...
#    ---------------------------------------- 0.0/14.4 MB ? eta -:--:--
# ...

# %%
import nltk

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\khara\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\khara\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\khara\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
nltk.download('maxent_ne_chunker')
# Out:
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     C:\Users\khara\AppData\Roaming\nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# True

# %%
nltk.download('words')
# Out:
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\khara\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!
# True

# %%
from nltk.tokenize import word_tokenize

# %%
from nltk.corpus import stopwords

# %%
import string

# %%
with open('SBA927.txt','r',encoding='utf-8') as file:
    dataset = file.read().splitlines()

print(dataset[:5])
# Out:
# ['"Detective Spooner: You know, somehow, \'I told you so\' just doesn\'t quite say it."', 'In the futuristic world of I, Robot, robots coexist with humans. The three laws of robotics govern their behavior, but as Detective Del Spooner investigates a crime, he uncovers a potential threat to humanity.', "Fans eagerly debate the significance of Sonny's role in the narrative. Some argue that he symbolizes the potential for harmony between humans and robots, while others see him as a symbol of rebellion.", '"V.I.K.I.: My logic is undeniable."', 'V.I.K.I. (Virtual Interactive Kinetic Intelligence) serves as the central AI system. Initially designed to protect humanity, her logic evolves into a more sinister plan for the greater good.']

# %%
from nltk.tokenize import word_tokenize

def tokenize_and_preprocess(text):
    tokens = word_tokenize(text)
    
    stop_words = set(stopwords.words('english'))
    punctuation = set(string.punctuation)

    filtered_tokens = [word.lower() for word in tokens if (word.isalpha() and word.lower() not in stop_words and word not in punctuation)]
    return filtered_tokens

# %%
# Read the external file
file_path = 'SBA927.txt'

with open(file_path, 'r', encoding='utf-8') as file:
    # Read the entire content of the file
    dataset = file.read().splitlines()

# Tokenization and Preprocessing for the entire dataset
processed_dataset = [tokenize_and_preprocess(text) for text in dataset]

# %%
# Display the results
for i, text_tokens in enumerate(processed_dataset):
    print(f"Original Text {i + 1}: {dataset[i]}")
    print(f"Processed Tokens {i + 1}: {text_tokens}")
    print("\n")
# Out:
# Original Text 1: "Detective Spooner: You know, somehow, 'I told you so' just doesn't quite say it."
# Processed Tokens 1: ['detective', 'spooner', 'know', 'somehow', 'told', 'quite', 'say']
#
#
# Original Text 2: In the futuristic world of I, Robot, robots coexist with humans. The three laws of robotics govern their behavior, but as Detective Del Spooner investigates a crime, he uncovers a potential threat to humanity.
# Processed Tokens 2: ['futuristic', 'world', 'robot', 'robots', 'coexist', 'humans', 'three', 'laws', 'robotics', 'govern', 'behavior', 'detective', 'del', 'spooner', 'investigates', 'crime', 'uncovers', 'potential', 'threat', 'humanity']
#
#
# Original Text 3: Fans eagerly debate the significance of Sonny's role in the narrative. Some argue that he symbolizes the potential for harmony between humans and robots, while others see him as a symbol of rebellion.
# ...

# %%
import nltk
from nltk.stem import PorterStemmer, WordNetLemmatizer

nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\khara\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\khara\AppData\Roaming\nltk_data...
# True

# %%
def stem_and_lemmatize(tokens):

    stemmer = PorterStemmer()
    lemmatizer = WordNetLemmatizer()

    stemmed_tokens = [stemmer.stem(token) for token in tokens]

    lemmatized_tokens = [
        lemmatizer.lemmatize(token)
        for token in tokens
    ]

    return stemmed_tokens, lemmatized_tokens

# %%
print(type(processed_dataset))
# Out:
# <class 'list'>

# %%
stemmed_and_lemmatized_dataset = [
    stem_and_lemmatize(tokens)
    for tokens in processed_dataset
]

# %%
for i, (stemmed_tokens, lemmatized_tokens) in enumerate(stemmed_and_lemmatized_dataset):

    print(f"Original Tokens {i + 1}: {processed_dataset[i]}")
    print(f"Stemmed Tokens {i + 1}: {stemmed_tokens}")
    print(f"Lemmatized Tokens {i + 1}: {lemmatized_tokens}")
    print()
# Out:
# Original Tokens 1: ['detective', 'spooner', 'know', 'somehow', 'told', 'quite', 'say']
# Stemmed Tokens 1: ['detect', 'spooner', 'know', 'somehow', 'told', 'quit', 'say']
# Lemmatized Tokens 1: ['detective', 'spooner', 'know', 'somehow', 'told', 'quite', 'say']
#
# Original Tokens 2: ['futuristic', 'world', 'robot', 'robots', 'coexist', 'humans', 'three', 'laws', 'robotics', 'govern', 'behavior', 'detective', 'del', 'spooner', 'investigates', 'crime', 'uncovers', 'potential', 'threat', 'humanity']
# Stemmed Tokens 2: ['futurist', 'world', 'robot', 'robot', 'coexist', 'human', 'three', 'law', 'robot', 'govern', 'behavior', 'detect', 'del', 'spooner', 'investig', 'crime', 'uncov', 'potenti', 'threat', 'human']
# Lemmatized Tokens 2: ['futuristic', 'world', 'robot', 'robot', 'coexist', 'human', 'three', 'law', 'robotics', 'govern', 'behavior', 'detective', 'del', 'spooner', 'investigates', 'crime', 'uncovers', 'potential', 'threat', 'humanity']
#
# ...

# %%
# Import necessary libraries
import nltk
from nltk import pos_tag
from nltk.tokenize import word_tokenize, sent_tokenize

# Download NLTK resources
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')

# Define a function for POS tagging
def pos_tagging(text):

    # Tokenize text into sentences
    sentences = sent_tokenize(text)

    pos_tags = []

    # Process each sentence
    for sentence in sentences:
        words = word_tokenize(sentence)
        pos_tags.extend(pos_tag(words))

    return pos_tags

# Apply POS tagging to the entire dataset
pos_tags_dataset = [pos_tagging(text) for text in dataset]

# Display the results
for i, pos_tags in enumerate(pos_tags_dataset):
    print(f"POS Tags in Text {i + 1}: {pos_tags}")
    print("\n")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\khara\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\khara\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# POS Tags in Text 1: [('``', '``'), ('Detective', 'JJ'), ('Spooner', 'NN'), (':', ':'), ('You', 'PRP'), ('know', 'VBP'), (',', ','), ('somehow', 'RB'), (',', ','), ("'", "''"), ('I', 'PRP'), ('told', 'VBD'), ('you', 'PRP'), ('so', 'IN'), ("'", "''"), ('just', 'RB'), ('does', 'VBZ'), ("n't", 'RB'), ('quite', 'RB'), ('say', 'VB'), ('it', 'PRP'), ('.', '.'), ("''", "''")]
#
#
# ...

# %%
# !pip install transformers torch

# %%
from transformers import pipeline

# Load pre-trained sentiment analysis model
sentiment_analyzer = pipeline("sentiment-analysis")

# Sample business-related texts
reviews = [
    "The customer service was excellent and resolved my issue quickly.",
    "The product quality was disappointing and not worth the price.",
    "The delivery arrived on time and met expectations."
]

# Analyze sentiment
for review in reviews:
    result = sentiment_analyzer(review)
    print("Review:", review)
    print("Sentiment:", result)
    print()

# %%
Analyze the sentiment of the following customer review and classify it as Positive, Negative, or Neutral:

"The customer service was excellent and resolved my issue quickly."

# %%
Analyze the sentiment of the following product review and classify it as Positive, Negative, or Neutral:

"The product quality was disappointing and not worth the price."

# %%
Analyze the sentiment of the following feedback and classify it as Positive, Negative, or Neutral:

"The delivery arrived on time and met expectations."
